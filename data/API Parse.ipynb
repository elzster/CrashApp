# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from pprint import pprint

# %%
url = 'https://data.cityofnewyork.us/resource/h9gi-nx95.json'
api_key = '6d9tjn00t42qylc8dyz47g7delanctoeesdaov6csoqtr0j6o5'

# %%
# req=requests.get(url)

# #each time you run this you will burn through your daily amount.
# parsed = json.loads(req.text)

# pprint(parsed, depth=3)

# %%
# datafile = pd.read_csv('US_Accidents_May19.csv')

# %%
# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("h9gi-nx95", limit=1500000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df
# Out:
#                       crash_date crash_time        borough zip_code  \
# 0        2019-04-04T00:00:00.000      22:30       BROOKLYN    11207
# 1        2019-04-25T00:00:00.000      17:22  STATEN ISLAND    10301
# 2        2019-04-13T00:00:00.000      15:45            NaN      NaN
# 3        2019-04-28T00:00:00.000      15:51         QUEENS    11373
# 4        2019-04-04T00:00:00.000      15:10         QUEENS    11372
# ...                          ...        ...            ...      ...
# 1499995  2013-05-31T00:00:00.000      14:30            NaN      NaN
# 1499996  2013-05-24T00:00:00.000       8:25         QUEENS    11385
# 1499997  2013-05-24T00:00:00.000      16:30            NaN      NaN
# 1499998  2013-06-07T00:00:00.000       9:20      MANHATTAN    10019
# 1499999  2013-05-20T00:00:00.000      15:05      MANHATTAN    10012
#
#            latitude    longitude  \
# 0        40.6544270  -73.8908000
# 1        40.6265450  -74.0915900
# 2        40.7404500  -73.8443760
# 3        40.7445500  -73.8737800
# 4        40.7479440  -73.8809000
# ...             ...          ...
# 1499995         NaN          NaN
# 1499996  40.7004089  -73.9036747
# 1499997         NaN          NaN
# 1499998  40.7665617  -73.9904225
# 1499999  40.7209387  -73.9937950
#
#                                                   location  \
# 0        {'type': 'Point', 'coordinates': [-73.8908, 40...
# 1        {'type': 'Point', 'coordinates': [-74.09159, 4...
# 2        {'type': 'Point', 'coordinates': [-73.844376, ...
# 3        {'type': 'Point', 'coordinates': [-73.87378, 4...
# 4        {'type': 'Point', 'coordinates': [-73.8809, 40...
# ...                                                    ...
# 1499995                                                NaN
# 1499996  {'type': 'Point', 'coordinates': [-73.9036747,...
# 1499997                                                NaN
# 1499998  {'type': 'Point', 'coordinates': [-73.9904225,...
# 1499999  {'type': 'Point', 'coordinates': [-73.993795, ...
#
#                            on_street_name                   off_street_name  \
# 0        WORTMAN AVENUE                                      ALABAMA AVENUE
# 1        EDDY STREET                                      VICTORY BOULEVARD
# 2        LONG ISLAND EXPRESSWAY                                         NaN
# 3        FORLEY STREET                                        LAMONT AVENUE
# 4                                     NaN                               NaN
# ...                                   ...                               ...
# 1499995                               NaN                               NaN
# 1499996  MYRTLE AVENUE                     SENECA AVENUE
# 1499997  WEST STREET                       CANAL STREET
# 1499998  10 AVENUE                         WEST 53 STREET
# 1499999  BOWERY                            SPRING STREET
#
#         number_of_persons_injured  ... collision_id  \
# 0                               0  ...      4109395
# 1                               0  ...      4120950
# 2                               0  ...      4113851
# 3                               1  ...      4122130
# 4                               0  ...      4108822
# ...                           ...  ...          ...
# 1499995                         0  ...       298264
# 1499996                         2  ...       216461
# 1499997                         0  ...         2754
# 1499998                         0  ...        41572
# 1499999                         0  ...         7438
#
#                           vehicle_type_code1             vehicle_type_code2  \
# 0                                        Bus                          Sedan
# 1                                      Sedan                          Sedan
# 2        Station Wagon/Sport Utility Vehicle                          Sedan
# 3                                       Bike                            NaN
# 4        Station Wagon/Sport Utility Vehicle                      Box Truck
# ...                                      ...                            ...
# 1499995        SPORT UTILITY / STATION WAGON  SPORT UTILITY / STATION WAGON
# 1499996                                  BUS              PASSENGER VEHICLE
# 1499997                    PASSENGER VEHICLE                            VAN
# 1499998                                  VAN              PASSENGER VEHICLE
# 1499999                    PASSENGER VEHICLE                           TAXI
#
#         contributing_factor_vehicle_3 vehicle_type_code_3  \
# 0                                 NaN                 NaN
# 1                         Unspecified               Sedan
# 2                                 NaN                 NaN
# 3                                 NaN                 NaN
# 4                                 NaN                 NaN
# ...                               ...                 ...
# 1499995                           NaN                 NaN
# 1499996                           NaN                 NaN
# 1499997                           NaN                 NaN
# 1499998                           NaN                 NaN
# 1499999                           NaN                 NaN
#
#                                 cross_street_name  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4        85-14     ROOSEVELT AVENUE
# ...                                           ...
# 1499995  P/L OF 2626 HYLAN BOULEVARD
# 1499996                                       NaN
# 1499997                                       NaN
# 1499998                                       NaN
# 1499999                                       NaN
#
#         contributing_factor_vehicle_4 contributing_factor_vehicle_5  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
# ...                               ...                           ...
# 1499995                           NaN                           NaN
# 1499996                           NaN                           NaN
# 1499997                           NaN                           NaN
# 1499998                           NaN                           NaN
# 1499999                           NaN                           NaN
#
#         vehicle_type_code_4 vehicle_type_code_5
# 0                       NaN                 NaN
# 1                       NaN                 NaN
# 2                       NaN                 NaN
# 3                       NaN                 NaN
# 4                       NaN                 NaN
# ...                     ...                 ...
# 1499995                 NaN                 NaN
# 1499996                 NaN                 NaN
# 1499997                 NaN                 NaN
# 1499998                 NaN                 NaN
# 1499999                 NaN                 NaN
#
# [1500000 rows x 29 columns]

# %%
df = pd.read_json('dataset.json')

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-ca6957407c8e> in <module>
#       5 cur.execute("CREATE TABLE t (col1, col2);") # use your column names here
#       6
# ----> 7 with open('data.csv','rb') as fin: # `with` statement available in 2.5+
#       8     # csv.DictReader uses first line in file for column headings by default
#       9     dr = csv.DictReader(fin) # comma is default delimiter
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.csv'
