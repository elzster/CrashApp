# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from pprint import pprint

# %%
url = 'https://data.cityofnewyork.us/resource/h9gi-nx95.json'
api_key = '6d9tjn00t42qylc8dyz47g7delanctoeesdaov6csoqtr0j6o5'

# %%
# req=requests.get(url)

# #each time you run this you will burn through your daily amount.
# parsed = json.loads(req.text)

# pprint(parsed, depth=3)

# %%
# datafile = pd.read_csv('US_Accidents_May19.csv')

# %%
# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("h9gi-nx95", limit=3000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df
clean_df = results_df.drop(columns="location")
# results_df.columns
# results_df.to_csv('test.csv')

# %%
clean_df.head()
# Out:
#                 crash_date crash_time    borough zip_code    latitude  \
# 0  2014-11-03T00:00:00.000       8:24     QUEENS    11370  40.7601424
# 1  2014-11-24T00:00:00.000       9:55     QUEENS    11368  40.7581320
# 2  2014-11-13T00:00:00.000       6:28     QUEENS    11423  40.7169676
# 3  2014-11-26T00:00:00.000      21:45   BROOKLYN    11207  40.6795349
# 4  2014-11-03T00:00:00.000      16:53  MANHATTAN    10012  40.7203211
#
#      longitude                    on_street_name  \
# 0  -73.8966215  30 AVENUE
# 1  -73.8569515  NORTHERN BOULEVARD
# 2  -73.7643735  89 AVENUE
# 3  -73.9004708  BUSHWICK AVENUE
# 4  -73.9940403  KENMARE STREET
#
#                     off_street_name number_of_persons_injured  \
# 0  71 STREET                                                0
# 1  112 PLACE                                                0
# 2  197 STREET                                               0
# 3  CONWAY STREET                                            0
# 4  BOWERY                                                   0
#
#   number_of_persons_killed  ... collision_id             vehicle_type_code1  \
# 0                        0  ...      2818220              PASSENGER VEHICLE
# 1                        0  ...      3107673              PASSENGER VEHICLE
# 2                        0  ...      2823174  SPORT UTILITY / STATION WAGON
# 3                        0  ...      3126945              PASSENGER VEHICLE
# 4                        0  ...      2818252                            VAN
#
#               vehicle_type_code2 cross_street_name  \
# 0              PASSENGER VEHICLE               NaN
# 1  SPORT UTILITY / STATION WAGON               NaN
# 2                        UNKNOWN               NaN
# 3              PASSENGER VEHICLE               NaN
# 4  SPORT UTILITY / STATION WAGON               NaN
#
#   contributing_factor_vehicle_3 vehicle_type_code_3  \
# 0                           NaN                 NaN
# 1                           NaN                 NaN
# 2                           NaN                 NaN
# 3                           NaN                 NaN
# 4                           NaN                 NaN
#
#   contributing_factor_vehicle_4 vehicle_type_code_4  \
# 0                           NaN                 NaN
# 1                           NaN                 NaN
# 2                           NaN                 NaN
# 3                           NaN                 NaN
# 4                           NaN                 NaN
#
#   contributing_factor_vehicle_5 vehicle_type_code_5
# 0                           NaN                 NaN
# 1                           NaN                 NaN
# 2                           NaN                 NaN
# 3                           NaN                 NaN
# 4                           NaN                 NaN
#
# [5 rows x 28 columns]

# %%
import sqlite3
conn = sqlite3.connect('test.sqlite')
clean_df.to_sql('nyctable', conn, if_exists='replace', index=False)
pd.read_sql('select * from nyctable', conn)
# Out:
#                    crash_date crash_time        borough zip_code    latitude  \
# 0     2014-11-03T00:00:00.000       8:24         QUEENS    11370  40.7601424
# 1     2014-11-24T00:00:00.000       9:55         QUEENS    11368  40.7581320
# 2     2014-11-13T00:00:00.000       6:28         QUEENS    11423  40.7169676
# 3     2014-11-26T00:00:00.000      21:45       BROOKLYN    11207  40.6795349
# 4     2014-11-03T00:00:00.000      16:53      MANHATTAN    10012  40.7203211
# ...                       ...        ...            ...      ...         ...
# 2995  2014-11-22T00:00:00.000       9:00  STATEN ISLAND    10310  40.6292495
# 2996  2014-11-11T00:00:00.000      17:05       BROOKLYN    11203  40.6524639
# 2997  2014-11-18T00:00:00.000       7:00           None     None        None
# 2998  2014-11-20T00:00:00.000      17:30           None     None  40.7354267
# 2999  2014-11-02T00:00:00.000       8:30         QUEENS    11433  40.6876885
#
#         longitude                    on_street_name  \
# 0     -73.8966215  30 AVENUE
# 1     -73.8569515  NORTHERN BOULEVARD
# 2     -73.7643735  89 AVENUE
# 3     -73.9004708  BUSHWICK AVENUE
# 4     -73.9940403  KENMARE STREET
# ...           ...                               ...
# 2995  -74.1232208  CLOVE ROAD
# 2996  -73.9228481  CHURCH AVENUE
# 2997         None                              None
# 2998  -73.8446465                              None
# 2999  -73.7925589  155 STREET
#
#                        off_street_name number_of_persons_injured  \
# 0     71 STREET                                                0
# 1     112 PLACE                                                0
# 2     197 STREET                                               0
# 3     CONWAY STREET                                            0
# 4     BOWERY                                                   0
# ...                                ...                       ...
# 2995  DELAFIELD AVENUE                                         0
# 2996  KINGS HIGHWAY                                            0
# 2997                              None                         1
# 2998                              None                         0
# 2999  113 AVENUE                                               0
#
#      number_of_persons_killed  ... collision_id  \
# 0                           0  ...      2818220
# 1                           0  ...      3107673
# 2                           0  ...      2823174
# 3                           0  ...      3126945
# 4                           0  ...      2818252
# ...                       ...  ...          ...
# 2995                        0  ...      2828378
# 2996                        0  ...      2822437
# 2997                        0  ...      2928237
# 2998                        0  ...      2827789
# 2999                        0  ...      2817579
#
#                  vehicle_type_code1              vehicle_type_code2  \
# 0                 PASSENGER VEHICLE               PASSENGER VEHICLE
# 1                 PASSENGER VEHICLE   SPORT UTILITY / STATION WAGON
# 2     SPORT UTILITY / STATION WAGON                         UNKNOWN
# 3                 PASSENGER VEHICLE               PASSENGER VEHICLE
# 4                               VAN   SPORT UTILITY / STATION WAGON
# ...                             ...                             ...
# 2995  SPORT UTILITY / STATION WAGON   SPORT UTILITY / STATION WAGON
# 2996  SPORT UTILITY / STATION WAGON               PASSENGER VEHICLE
# 2997              PASSENGER VEHICLE  LARGE COM VEH(6 OR MORE TIRES)
# 2998  SPORT UTILITY / STATION WAGON   SPORT UTILITY / STATION WAGON
# 2999              PASSENGER VEHICLE                             VAN
#
#      cross_street_name contributing_factor_vehicle_3 vehicle_type_code_3  \
# 0                 None                          None                None
# 1                 None                          None                None
# 2                 None                          None                None
# 3                 None                          None                None
# 4                 None                          None                None
# ...                ...                           ...                 ...
# 2995              None                          None                None
# 2996              None                          None                None
# 2997              None                          None                None
# 2998              None                          None                None
# 2999              None                          None                None
#
#      contributing_factor_vehicle_4 vehicle_type_code_4  \
# 0                             None                None
# 1                             None                None
# 2                             None                None
# 3                             None                None
# 4                             None                None
# ...                            ...                 ...
# 2995                          None                None
# 2996                          None                None
# 2997                          None                None
# 2998                          None                None
# 2999                          None                None
#
#      contributing_factor_vehicle_5 vehicle_type_code_5
# 0                             None                None
# 1                             None                None
# 2                             None                None
# 3                             None                None
# 4                             None                None
# ...                            ...                 ...
# 2995                          None                None
# 2996                          None                None
# 2997                          None                None
# 2998                          None                None
# 2999                          None                None
#
# [3000 rows x 28 columns]
